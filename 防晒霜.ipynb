# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
import re
import matplotlib
# %matplotlib inline
from scipy import stats
from scipy.stats import norm, skew

# %%
names= ['标题','原价（元）','库存','销量','描述分','服务分','物流分','人气','总评','保质期','化妆品净含量(g/ml)','防晒指数','适用对象','适合肤质','品牌','防晒分类','是否为特殊用途化妆品','功效','产地','简介']
dtype = 
data = pd.read_csv('C:/Users/Secretgarden/Desktop/防晒霜.csv',engine='python' ,encoding='utf-8',names=names)
data
# Out:
#                                                       标题  原价（元）       库存  \
# 0                                                     标题    NaN      NaN
# 1                     正品TJOY丁家宜美白防晒乳液spf30夏季防晒霜防紫外线裸买2送1   28.0   9294.0
# 2                         【天天特价】平价安热沙!日本近江兄弟小熊防水防汗隔离防晒乳霜   18.9   7180.0
# 3                       特价现货！泰国正品代购THANN紫苏隔离防晒霜女美白面部防水防晒  245.0    124.0
# 4                       玫琳凯防晒霜SPF20隔离辐射户外海边儿童旗舰店官方正品舒怡防晒  198.0  42780.0
# 5                 正品 Olay玉兰油多效修护防晒霜50g-SPF15 滋润保湿 隔离美白面霜  103.0   5997.0
# 6                限购1瓶 17年新版资生堂安热沙金瓶防晒霜ANESSA耐晒SPF50 60ml  165.5   1339.0
# 7                        【专柜正品】玉兰油三重隔离亮肤防晒乳 面部美白修复防晒霜 男女   75.0    610.0
# 8                         露兰姬娜防晒霜女30倍美白隔离防汗紫外线学生户外军训保湿补水   28.0    963.0
# 9                        贝美美白防晒隔离霜贝亦美防晒霜香楝太阳花柔白型齐发业2016正   88.8   3138.0
# 10                    包邮正品梵洁诗酪梨清新阳光防护乳PA+++50ml滋润型 美白防晒霜   39.9  47771.0
# 11                 日本专柜正品 POLA维斯美白防晒霜精华液SPF50++++清爽 现货速发  268.0    192.0
# ...

# %%
data = data[data['销量'].notnull()]

# %%
len(data)
# Out:
# 2355

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2355 entries, 1 to 2355
# Data columns (total 20 columns):
# 标题              2355 non-null object
# 原价（元）           2355 non-null float64
# 库存              2355 non-null float64
# 销量              2355 non-null object
# 描述分             2355 non-null float64
# 服务分             2355 non-null float64
# 物流分             2355 non-null float64
# 人气              2355 non-null float64
# 总评              2355 non-null float64
# 保质期             1386 non-null object
# 化妆品净含量(g/ml)    1627 non-null object
# 防晒指数            2008 non-null object
# 适用对象            1876 non-null object
# 适合肤质            1966 non-null object
# 品牌              2355 non-null object
# 防晒分类            2027 non-null object
# 是否为特殊用途化妆品      2354 non-null object
# 功效              2355 non-null object
# 产地              2355 non-null object
# 简介              1430 non-null object
# dtypes: float64(7), object(13)
# memory usage: 466.4+ KB
# None

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['标题', '原价（元）', '库存', '销量', '描述分', '服务分', '物流分', '人气', '总评', '保质期',
#        '化妆品净含量(g/ml)', '防晒指数', '适用对象', '适合肤质', '品牌', '防晒分类', '是否为特殊用途化妆品',
#        '功效', '产地', '简介'],
#       dtype='object')

# %% [markdown]
# **对响应变量做正态性检验**

# %%
sns.distplot(list(map(int,data['销量'])),fit = norm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-95e75115ae41> in <module>()
# ----> 1 sns.distplot(list(map(int,data['销量'])),fit = norm)
#
# ValueError: invalid literal for int() with base 10: '-'

# %%
type(data['销量'][1])
# Out:
# str

# %%
a = ['1','5','6']
b = list(map(int , a))

# %%
response_var_data = list(map(int,data['销量']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-bed5f52941bd> in <module>()
# ----> 1 response_var_data = list(map(int,data['销量']))
#
# ValueError: invalid literal for int() with base 10: '-'

# %%
'-23'.isalnum()
# Out:
# False

# %%
response_var_data = []
for i in data['销量']:
    try:
        int_data = int(i)
    except ValueError:
        pass
    response_var_data.append(int_data)

# %%
response_var_data[1]
# Out:
# 537

# %%
sns.distplot(np.log1p(response_var_data),fit = norm)
# Out:
# C:\Users\Secretgarden\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
